# %% [markdown]
# <a href="https://colab.research.google.com/github/yalyaaxie/DATA-MINING/blob/main/PRATIKUM%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

pd.options.display.max_rows = 9999 
df = pd.read_csv('data.csv.xls' , delimiter = ';')
df.head()
# Out:
#          nama_sentra      jenis_produk  jumlah_unit_usaha  \
# 0    Jatinegara Lio             Meubel                 45
# 1  PIK Penggilingan            Kap/Jok                  7
# 2  PIK Penggilingan         Tas/Sepatu                 45
# 3   PIK Pengilingan   Percetakan Aneka                 51
# 4         Rawa Sari     Tahu dan Tempe                100
#
#                              alamat      kelurahan     kecamatan   \
# 0            Jl.Raya Bekasi Gg. Lio         Cakung         Cakung
# 1              Jl.Raya Penggilingan         Cakung         Cakung
# 2               Jl.PIK penggilingan   Penggilingan         Cakung
# 3  Jl.PIK penggilingan Blok E Jatim   Penggilingan         Cakung
# 4                   Jl.Pramuka Sari  Cempaka Putih  Cempaka Putih
#
#          wilayah  tenaga_kerja  nilai_investasi  kapasitas_produksi satuan  \
# 0  Jakarta Timur         240.0     8.000000e+08             80000.0     kg
# ...

# %%
df.isnull().sum().sum()
# Out:
# 66

# %%
df = df.dropna()
df.isnull().sum().sum()
# Out:
# 0

# %%
df2 = df.apply(lambda x: x.astype(str).str.upper())
df2.head()
# Out:
#        nama_sentra    jenis_produk jumlah_unit_usaha                  alamat  \
# 0  JATINEGARA LIO           MEUBEL                45  JL.RAYA BEKASI GG. LIO
# 4       RAWA SARI   TAHU DAN TEMPE               100         JL.PRAMUKA SARI
# 5        CILANDAK            TEMPE                25        JL.H. DAWA JALIL
# 7          SEMPER   TAHU DAN TEMPE               286         JL.TIPAR CAKUNG
# 8        KALIBARU        IKAN ASIN                80            JL.KALI BARU
#
#        kelurahan     kecamatan           wilayah tenaga_kerja nilai_investasi  \
# 0         CAKUNG         CAKUNG    JAKARTA TIMUR        240.0     800000000.0
# 4  CEMPAKA PUTIH  CEMPAKA PUTIH    JAKARTA PUSAT        300.0    1000000000.0
# 5       CILANDAK       CILANDAK  JAKARTA SELATAN         75.0     250000000.0
# 7   SEMPER BARAT      CILINCING    JAKARTA UTARA         60.0     200000000.0
# 8      KALI BARU      CILINCING    JAKARTA UTARA        558.0    1860000000.0
#
# ...

# %%
len(df2[df2['wilayah']=='JAKARTA SELATAN'])
# Out:
# 9
